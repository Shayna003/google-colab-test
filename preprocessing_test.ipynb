# %% [markdown]
# <a href="https://colab.research.google.com/github/Shayna003/google-colab-test/blob/main/preprocessing_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# import libraries and set up the environment

# %%
#!pip install -r requirements.txt

import string
import pandas as pd
from nltk.corpus import stopwords
import nltk
import spacy

# %% [markdown]
# demonstration of lemmatizer

# %%
from nltk.stem import WordNetLemmatizer
wnl = WordNetLemmatizer()
print(wnl.lemmatize('dogs'))

print(wnl.lemmatize('churches'))

print(wnl.lemmatize('aardwolves'))

print(wnl.lemmatize('abaci'))

print(wnl.lemmatize('hardrock'))
# Out:
# dog
# church
# aardwolf
# abacus
# hardrock

# %% [markdown]
# preprocessing using nltk library

# %%
nltk.download('stopwords')
nltk.download('wordnet')
lemmatizer = nltk.stem.WordNetLemmatizer()
tokeniser = nltk.tokenize.WhitespaceTokenizer()

# %%
file_url = "https://raw.githubusercontent.com/Shayna003/google-colab-test/main/preprocessing_test.csv"
data_file = pd.read_csv(file_url) #reads dataset

# %%
def pre_processing():
    nlp = spacy.blank('en')
    data_file['text'] = data_file['text'].astype(str).str.lower() #makes all reviews lowercase
    punct = "\n\r" + string.punctuation
    data_file['text'] = data_file['text'].str.translate(str.maketrans('', '', punct)) #removes all punctuation
    stop = stopwords.words('english')
    data_file['text'] = data_file['text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)])) # removes stopwords

    data_file['text'] = data_file['text'].map(lemmatisation)  #lemmatisation : changing words with same meaning into one word

def lemmatisation(text):
    s = ''
    for w in tokeniser.tokenize(text):
      s += lemmatizer.lemmatize(w)
      s += ' '
    s = s[:-1]
    return s

# %%
data_file.head(3)
# Out:
#                                                 text
# 0                          dogs don't go to churches
# 1  CAPITAL letters, punctuations and some stop wo...
# 2                                         🔥 emoji :)

# %%
pre_processing()

# %%
data_file.head(3)
# Out:
#                                    text
# 0                    dog dont go church
# 1  capital letter punctuation stop word
# 2                               🔥 emoji

# %% [markdown]
# notice how lemmatizer turned "dogs" to dog, removed special characters, stop words, and turned all letters to lower case.
